# %% [markdown]
# My project is going to be a solar system simulator, where planets bounce off of each other at varying elaticity, breaking energy and velocity. I currently have the orbital mechenics programmed in, and proper collision mechanism is still work in progress. Below shows the distance between a space station and the moon, where the graph hits zero is where the collision will happen (The collision is currently very premitive).
#
# The current challenge is correctly modeling the collision mechanisms between two bodies in three dimentions. The rest is pretty much sorted out already.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('Figure_8.png')
imgplot = plt.imshow(img)
plt.show()
